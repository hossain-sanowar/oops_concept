# %%
import torch

# %%
import torch.nn as nn

# %%
torch.tensor([1,2,3])
# Out:
# tensor([1, 2, 3])

# %%
torch.tensor([[1,2,3],[4,5,6]])
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.eye(3)
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %%
torch.linspace(0,100,6)
# Out:
# tensor([  0.,  20.,  40.,  60.,  80., 100.])

# %%
torch.arange(0,10,3)
# Out:
# tensor([0, 3, 6, 9])

# %%
torch.full((2,3),8)
# Out:
# tensor([[8, 8, 8],
#         [8, 8, 8]])

# %%
torch.rand(4,5)
# Out:
# tensor([[0.0823, 0.5215, 0.2807, 0.0122, 0.9892],
#         [0.0323, 0.6160, 0.9101, 0.1646, 0.3316],
#         [0.2379, 0.8320, 0.1612, 0.5360, 0.1245],
#         [0.3838, 0.8211, 0.1088, 0.5400, 0.9008]])

# %%
torch.randint(0,5,(2,3))
# Out:
# tensor([[2, 1, 0],
#         [4, 3, 2]])

# %%
data=torch.randn(4,5)

# %%
data[0]
# Out:
# tensor([-0.1698,  1.3032, -0.6299, -0.4819,  1.1216])

# %%
data[0:2]
# Out:
# tensor([[-0.1698,  1.3032, -0.6299, -0.4819,  1.1216],
#         [-0.8004, -0.6791, -1.0680,  1.5691, -0.8653]])

# %%
data[0:1,1]
# Out:
# tensor([1.3032])

# %%
data.numel()
# Out:
# 20

# %%
data.shape
# Out:
# torch.Size([4, 5])
