# %%
import torch

# %%
import torch.nn as nn

# %%
torch.tensor([1,2,3])
# Out:
# tensor([1, 2, 3])

# %%
torch.tensor([[1,2,3],[4,5,6]])
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.eye(3)
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %%
torch.linspace(0,100,6)
# Out:
# tensor([  0.,  20.,  40.,  60.,  80., 100.])

# %%
torch.arange(0,10,3)
# Out:
# tensor([0, 3, 6, 9])

# %%
torch.full((2,3),8)
# Out:
# tensor([[8, 8, 8],
#         [8, 8, 8]])
