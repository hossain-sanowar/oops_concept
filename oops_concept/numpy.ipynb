# %%
import numpy as np

# %% [markdown]
# # creating arrays

# %%
d1=np.array([1,2,3])

# %%
d1[0]
# Out:
# np.int64(1)

# %%
d2=np.array([[4,5,6],[7,8,9]])

# %%
d2[0][0]
# Out:
# np.int64(4)

# %%
zero=np.zeros((3,3))

# %%
zero[0][0]
# Out:
# np.float64(0.0)
