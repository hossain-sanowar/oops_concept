# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8, 9],
},
    index=[0, 1, 2])

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.loc[0,'a':'b']
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
df.iloc[0,0]
# Out:
# np.int64(1)

# %%
df.iloc[0,0]=5

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9
