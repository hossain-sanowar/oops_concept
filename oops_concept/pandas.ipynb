# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8, 9],
},
    index=[0, 1, 2])

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.loc[0,'a':'b']
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
df.iloc[0,0]
# Out:
# np.int64(1)

# %%
df.iloc[0,0]=5

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.iloc[0, 0]
# Out:
# np.int64(5)

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.sum()
# Out:
# a    10
# b    15
# c    24
# dtype: int64

# %%
df.min()
# Out:
# a    2
# b    4
# c    7
# dtype: int64

# %%
df.max()
# Out:
# a    5
# b    6
# c    9
# dtype: int64

# %%
df['a'].value_counts()
# Out:
# a
# 5    1
# 2    1
# 3    1
# Name: count, dtype: int64

# %%
df['a'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#               a    b    c
# count  3.000000  3.0  3.0
# mean   3.333333  5.0  8.0
# std    1.527525  1.0  1.0
# min    2.000000  4.0  7.0
# 25%    2.500000  4.5  7.5
# 50%    3.000000  5.0  8.0
# 75%    4.000000  5.5  8.5
# max    5.000000  6.0  9.0

# %%
df.head(2)
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8

# %%
df.tail(2)
# Out:
#    a  b  c
# 1  2  5  8
# 2  3  6  9

# %%
df.sample(2)
# Out:
#    a  b  c
# 0  5  4  7
# 2  3  6  9

# %%
df.isnull()
# Out:
#        a      b      c
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
df.isnull().sum()
# Out:
# a    0
# b    0
# c    0
# dtype: int64

# %%
df.mean()
# Out:
# a    3.333333
# b    5.000000
# c    8.000000
# dtype: float64

# %%
df.median()
# Out:
# a    3.0
# b    5.0
# c    8.0
# dtype: float64

# %%
df.quantile()
# Out:
# a    3.0
# b    5.0
# c    8.0
# Name: 0.5, dtype: float64

# %%
df.groupby('a').mean()
# Out:
#      b    c
# a
# 2  5.0  8.0
# 3  6.0  9.0
# 5  4.0  7.0

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.groupby(level=0).mean()
# Out:
#      a    b    c
# 0  5.0  4.0  7.0
# 1  2.0  5.0  8.0
# 2  3.0  6.0  9.0

# %%
df.shift(1)
# Out:
#      a    b    c
# 0  NaN  NaN  NaN
# 1  5.0  4.0  7.0
# 2  2.0  5.0  8.0

# %%
df.shift(2)
# Out:
#      a    b    c
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  5.0  4.0  7.0

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.max()
# Out:
# a    5
# b    6
# c    9
# dtype: int64

# %%
df.min()
# Out:
# a    2
# b    4
# c    7
# dtype: int64

# %%
df1=pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8, 9],
},
    index=[0, 1, 2])

# %%
df1
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df+df1
# Out:
#    a   b   c
# 0  6   8  14
# 1  4  10  16
# 2  6  12  18

# %%
df.merge(df1, on='a')
# Out:
#    a  b_x  c_x  b_y  c_y
# 0  2    5    8    5    8
# 1  3    6    9    6    9

# %%
df.merge(df1, on='b',how='left')
# Out:
#    a_x  b  c_x  a_y  c_y
# 0    5  4    7    1    7
# 1    2  5    8    2    8
# 2    3  6    9    3    9

# %%
df.merge(df1, on='c',how='right')
# Out:
#    a_x  b_x  c  a_y  b_y
# 0    5    4  7    1    4
# 1    2    5  8    2    5
# 2    3    6  9    3    6

# %%
df.merge(df1, on='c',how='inner')
# Out:
#    a_x  b_x  c  a_y  b_y
# 0    5    4  7    1    4
# 1    2    5  8    2    5
# 2    3    6  9    3    6

# %%
pd.concat([df, df1])
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
pd.concat([df, df1], axis=1)
# Out:
#    a  b  c  a  b  c
# 0  5  4  7  1  4  7
# 1  2  5  8  2  5  8
# 2  3  6  9  3  6  9

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9
