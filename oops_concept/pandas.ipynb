# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8, 9],
},
    index=[0, 1, 2])

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.loc[0,'a':'b']
# Out:
# a    1
# b    4
# Name: 0, dtype: int64

# %%
df.iloc[0,0]
# Out:
# np.int64(1)

# %%
df.iloc[0,0]=5

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.iloc[0, 0]
# Out:
# np.int64(5)

# %%
df
# Out:
#    a  b  c
# 0  5  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.sum()
# Out:
# a    10
# b    15
# c    24
# dtype: int64

# %%
df.min()
# Out:
# a    2
# b    4
# c    7
# dtype: int64

# %%
df.max()
# Out:
# a    5
# b    6
# c    9
# dtype: int64
